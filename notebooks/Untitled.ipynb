# %% [markdown]
# Import the necessary moduels

# %%
import pandas as pd

# %% [markdown]
# Read the data into a dataframe

# %%
df = pd.read_csv('../data/kepler.csv')

# %% [markdown]
# View the first and last rows in the dataframe.

# %%
#the first 5 rows
df.head()
# Out:
#                    # name planet_status   mass  mass_error_min  \
# 0   OGLE-2016-BLG-1469L b     Confirmed  13.60            3.00
# 1                11 Com b     Confirmed  19.40            1.50
# 2                11 Oph b     Confirmed  21.00            3.00
# 3                11 UMi b     Confirmed  10.50            2.47
# 4                14 And b     Confirmed   5.33            0.57
#
#    mass_error_max  mass_sini  mass_sini_error_min  mass_sini_error_max  \
# 0            3.00        NaN                  NaN                  NaN
# 1            1.50      19.40                 1.50                 1.50
# 2            3.00        NaN                  NaN                  NaN
# 3            2.47      10.50                 2.47                 2.47
# 4            0.57       5.33                 0.57                 0.57
#
#    radius  radius_error_min  ...  star_sp_type  star_age  star_age_error_min  \
# 0     NaN               NaN  ...           NaN       NaN                 NaN
# 1     NaN               NaN  ...        G8 III       NaN                 NaN
# 2     NaN               NaN  ...            M9     0.011               0.002
# 3     NaN               NaN  ...         K4III     1.560               0.540
# 4     NaN               NaN  ...         K0III       NaN                 NaN
#
#    star_age_error_max  star_teff  star_teff_error_min  star_teff_error_max  \
# 0                 NaN        NaN                  NaN                  NaN
# 1                 NaN     4742.0                100.0                100.0
# 2               0.002     2375.0                175.0                175.0
# 3               0.540     4340.0                 70.0                 70.0
# 4                 NaN     4813.0                 20.0                 20.0
#
#    star_detected_disc  star_magnetic_field  star_alternate_names
# 0                 NaN                  NaN                   NaN
# 1                 NaN                  NaN                   NaN
# 2                 NaN                  NaN                   NaN
# 3                 NaN                  NaN                   NaN
# 4                 NaN                  NaN                   NaN
#
# [5 rows x 98 columns]

# %%
#the last 5 rows
df.tail()
# Out:
#          # name planet_status    mass  mass_error_min  mass_error_max  \
# 3727  tau Gem b     Confirmed  20.600             NaN             NaN
# 3728  ups And b     Confirmed   0.620           0.090             inf
# 3729  ups And c     Confirmed   9.100           2.900           5.000
# 3730  ups And d     Confirmed  23.580           2.295           2.931
# 3731  ups And e     Confirmed   1.059           0.028           0.028
#
#       mass_sini  mass_sini_error_min  mass_sini_error_max  radius  \
# 3727     20.600                  NaN                  NaN     NaN
# 3728      0.620                0.090                0.090     NaN
# 3729      1.800                0.260                0.260     NaN
# 3730     10.190                  NaN                  NaN     NaN
# 3731      1.059                0.028                0.028     NaN
#
#       radius_error_min  ...  star_sp_type  star_age  star_age_error_min  \
# 3727               NaN  ...         K2III      1.22                0.76
# 3728               NaN  ...          F8 V      3.80                1.00
# 3729               NaN  ...          F8 V      3.80                1.00
# 3730               NaN  ...          F8 V      3.80                1.00
# 3731               NaN  ...          F8 V      3.80                1.00
#
#       star_age_error_max  star_teff  star_teff_error_min  star_teff_error_max  \
# 3727                0.76     4388.0                 25.0                 25.0
# 3728                1.00     6212.0                 80.0                 80.0
# 3729                1.00     6212.0                 80.0                 80.0
# 3730                1.00     6212.0                 80.0                 80.0
# 3731                1.00     6212.0                 80.0                 80.0
#
#       star_detected_disc  star_magnetic_field  star_alternate_names
# 3727                 NaN                  NaN                   NaN
# 3728                 NaN                  NaN                   NaN
# 3729                 NaN                  NaN                   NaN
# 3730                 NaN                  NaN                   NaN
# 3731                 NaN                  NaN                   NaN
#
# [5 rows x 98 columns]

# %%
#the first 10 rows
df.head(10)
# Out:
#                    # name planet_status   mass  mass_error_min  \
# 0   OGLE-2016-BLG-1469L b     Confirmed  13.60            3.00
# 1                11 Com b     Confirmed  19.40            1.50
# 2                11 Oph b     Confirmed  21.00            3.00
# 3                11 UMi b     Confirmed  10.50            2.47
# 4                14 And b     Confirmed   5.33            0.57
# 5                14 Her b     Confirmed   4.64            0.19
# 6              16 Cyg B b     Confirmed   1.68            0.07
# 7                18 Del b     Confirmed  10.30             NaN
# 8              1I/2017 U1     Confirmed    NaN             NaN
# 9             1RXS 1609 b     Confirmed  14.00            3.00
#
#    mass_error_max  mass_sini  mass_sini_error_min  mass_sini_error_max  \
# 0            3.00        NaN                  NaN                  NaN
# 1            1.50      19.40                 1.50                 1.50
# 2            3.00        NaN                  NaN                  NaN
# 3            2.47      10.50                 2.47                 2.47
# 4            0.57       5.33                 0.57                 0.57
# 5            0.19       4.64                 0.19                 0.19
# 6            0.07       1.68                 0.07                 0.07
# 7             NaN      10.30                  NaN                  NaN
# 8             NaN        NaN                  NaN                  NaN
# 9            2.00        NaN                  NaN                  NaN
#
#      radius  radius_error_min  ...  star_sp_type  star_age  \
# 0       NaN               NaN  ...           NaN       NaN
# 1       NaN               NaN  ...        G8 III       NaN
# 2       NaN               NaN  ...            M9     0.011
# 3       NaN               NaN  ...         K4III     1.560
# 4       NaN               NaN  ...         K0III       NaN
# 5       NaN               NaN  ...          K0 V     5.100
# 6       NaN               NaN  ...        G2.5 V     8.000
# 7       NaN               NaN  ...         G6III       NaN
# 8  0.000002               NaN  ...           NaN       NaN
# 9  1.700000               NaN  ...           K7V     0.011
#
#    star_age_error_min  star_age_error_max  star_teff  star_teff_error_min  \
# 0                 NaN                 NaN        NaN                  NaN
# 1                 NaN                 NaN     4742.0                100.0
# 2               0.002               0.002     2375.0                175.0
# 3               0.540               0.540     4340.0                 70.0
# 4                 NaN                 NaN     4813.0                 20.0
# 5                 NaN                 NaN     5311.0                 87.0
# 6               1.800               1.800     5766.0                 60.0
# 7                 NaN                 NaN     4979.0                 18.0
# 8                 NaN                 NaN        NaN                  NaN
# 9               0.002               0.002     4060.0                200.0
#
#    star_teff_error_max  star_detected_disc  star_magnetic_field  \
# 0                  NaN                 NaN                  NaN
# 1                100.0                 NaN                  NaN
# 2                175.0                 NaN                  NaN
# 3                 70.0                 NaN                  NaN
# 4                 20.0                 NaN                  NaN
# 5                 87.0                 NaN                  NaN
# 6                 60.0                 NaN                  NaN
# 7                 18.0                 NaN                  NaN
# 8                  NaN                 NaN                  NaN
# 9                200.0                 NaN                  NaN
#
#    star_alternate_names
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
#
# [10 rows x 98 columns]

# %%
# the last 2 rows
df.tail(2)
# Out:
#          # name planet_status    mass  mass_error_min  mass_error_max  \
# 3730  ups And d     Confirmed  23.580           2.295           2.931
# 3731  ups And e     Confirmed   1.059           0.028           0.028
#
#       mass_sini  mass_sini_error_min  mass_sini_error_max  radius  \
# 3730     10.190                  NaN                  NaN     NaN
# 3731      1.059                0.028                0.028     NaN
#
#       radius_error_min  ...  star_sp_type  star_age  star_age_error_min  \
# 3730               NaN  ...          F8 V       3.8                 1.0
# 3731               NaN  ...          F8 V       3.8                 1.0
#
#       star_age_error_max  star_teff  star_teff_error_min  star_teff_error_max  \
# 3730                 1.0     6212.0                 80.0                 80.0
# 3731                 1.0     6212.0                 80.0                 80.0
#
#       star_detected_disc  star_magnetic_field  star_alternate_names
# 3730                 NaN                  NaN                   NaN
# 3731                 NaN                  NaN                   NaN
#
# [2 rows x 98 columns]

# %% [markdown]
# View a sample of 8 rows

# %%
df.sample(8)
# Out:
#                      # name planet_status     mass  mass_error_min  \
# 2036           Kepler-204 c     Confirmed      NaN             NaN
# 1049             KOI-1299 c     Confirmed   2.6300          0.4000
# 1603          Kepler-1401 b     Confirmed      NaN             NaN
# 3426  OGLE-2013-BLG-0102L b     Confirmed  13.6000          3.0000
# 1862          Kepler-1603 b     Confirmed      NaN             NaN
# 1746          Kepler-1513 b     Confirmed      NaN             NaN
# 2110            Kepler-23 b     Confirmed   0.0478          0.0091
# 2674           Kepler-473 b     Confirmed      NaN             NaN
#
#       mass_error_max  mass_sini  mass_sini_error_min  mass_sini_error_max  \
# 2036             NaN        NaN                  NaN                  NaN
# 1049            0.40       2.63                  0.4                  0.4
# 1603             NaN        NaN                  NaN                  NaN
# 3426            3.00        NaN                  NaN                  NaN
# 1862             NaN        NaN                  NaN                  NaN
# 1746             NaN        NaN                  NaN                  NaN
# 2110            0.01        NaN                  NaN                  NaN
# 2674             NaN        NaN                  NaN                  NaN
#
#       radius  radius_error_min  ...  star_sp_type  star_age  \
# 2036  0.1600            0.0350  ...           NaN       NaN
# 1049     NaN               NaN  ...         K2III       3.6
# 1603  0.1500            0.0160  ...           NaN       NaN
# 3426     NaN               NaN  ...           NaN       NaN
# 1862  0.1150            0.0170  ...           NaN       NaN
# 1746  0.7550            0.0650  ...           NaN       NaN
# 2110  0.1511            0.0068  ...           NaN       NaN
# 2674  0.3640            0.0600  ...           NaN       NaN
#
#       star_age_error_min  star_age_error_max  star_teff  star_teff_error_min  \
# 2036                 NaN                 NaN     5812.0               100.00
# 1049                 1.0                 0.6     5020.0                60.00
# 1603                 NaN                 NaN     5964.0               124.67
# 3426                 NaN                 NaN        NaN                  NaN
# 1862                 NaN                 NaN     6241.0               168.54
# 1746                 NaN                 NaN     5617.0               124.96
# 2110                 NaN                 NaN     5760.0               124.00
# 2674                 NaN                 NaN     5816.0                91.94
#
#       star_teff_error_max  star_detected_disc  star_magnetic_field  \
# 2036               100.00                 NaN                  NaN
# 1049                60.00                 NaN                  NaN
# 1603               104.96                 NaN                  NaN
# 3426                  NaN                 NaN                  NaN
# 1862               116.66                 NaN                  NaN
# 1746               176.78                 NaN                  NaN
# 2110               124.00                 NaN                  NaN
# 2674                74.23                 NaN                  NaN
#
#       star_alternate_names
# 2036                   NaN
# 1049                   NaN
# 1603                   NaN
# 3426                   NaN
# 1862                   NaN
# 1746                   NaN
# 2110                   NaN
# 2674                   NaN
#
# [8 rows x 98 columns]

# %% [markdown]
# Use the .describe() function to view qualitative measures of the data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3732 entries, 0 to 3731
# Data columns (total 98 columns):
# # name                        3732 non-null object
# planet_status                 3732 non-null object
# mass                          1586 non-null float64
# mass_error_min                1394 non-null float64
# mass_error_max                1380 non-null float64
# mass_sini                     868 non-null float64
# mass_sini_error_min           706 non-null float64
# mass_sini_error_max           705 non-null float64
# radius                        2826 non-null float64
# radius_error_min              2751 non-null float64
# radius_error_max              2751 non-null float64
# orbital_period                3595 non-null float64
# orbital_period_error_min      3471 non-null float64
# orbital_period_error_max      3472 non-null float64
# semi_major_axis               2256 non-null float64
# semi_major_axis_error_min     1259 non-null float64
# semi_major_axis_error_max     1259 non-null float64
# eccentricity                  1305 non-null float64
# eccentricity_error_min        1058 non-null float64
# eccentricity_error_max        1044 non-null float64
# inclination                   667 non-null float64
# inclination_error_min         629 non-null float64
# inclination_error_max         633 non-null float64
# angular_distance              663 non-null float64
# discovered                    3731 non-null float64
# updated                       3732 non-null object
# omega                         788 non-null float64
# omega_error_min               742 non-null float64
# omega_error_max               742 non-null float64
# tperi                         571 non-null float64
# tperi_error_min               524 non-null float64
# tperi_error_max               524 non-null float64
# tconj                         30 non-null float64
# tconj_error_min               30 non-null float64
# tconj_error_max               30 non-null float64
# tzero_tr                      632 non-null float64
# tzero_tr_error_min            591 non-null float64
# tzero_tr_error_max            591 non-null float64
# tzero_tr_sec                  15 non-null float64
# tzero_tr_sec_error_min        15 non-null float64
# tzero_tr_sec_error_max        15 non-null float64
# lambda_angle                  40 non-null float64
# lambda_angle_error_min        42 non-null float64
# lambda_angle_error_max        42 non-null float64
# impact_parameter              247 non-null float64
# impact_parameter_error_min    236 non-null float64
# impact_parameter_error_max    236 non-null float64
# tzero_vr                      26 non-null float64
# tzero_vr_error_min            24 non-null float64
# tzero_vr_error_max            24 non-null float64
# k                             462 non-null float64
# k_error_min                   462 non-null float64
# k_error_max                   462 non-null float64
# temp_calculated               277 non-null float64
# temp_calculated_error_min     37 non-null float64
# temp_calculated_error_max     37 non-null float64
# temp_measured                 34 non-null float64
# hot_point_lon                 0 non-null float64
# geometric_albedo              10 non-null float64
# geometric_albedo_error_min    9 non-null float64
# geometric_albedo_error_max    9 non-null float64
# log_g                         20 non-null float64
# publication_status            3732 non-null object
# detection_type                3732 non-null object
# mass_detection_type           582 non-null object
# radius_detection_type         379 non-null object
# alternate_names               179 non-null object
# molecules                     48 non-null object
# star_name                     3732 non-null object
# ra                            3732 non-null float64
# dec                           3732 non-null float64
# mag_v                         1522 non-null float64
# mag_i                         83 non-null float64
# mag_j                         2077 non-null float64
# mag_h                         2064 non-null float64
# mag_k                         2093 non-null float64
# star_distance                 2584 non-null float64
# star_distance_error_min       1053 non-null float64
# star_distance_error_max       1054 non-null float64
# star_metallicity              3348 non-null float64
# star_metallicity_error_min    2451 non-null float64
# star_metallicity_error_max    2451 non-null float64
# star_mass                     3354 non-null float64
# star_mass_error_min           2619 non-null float64
# star_mass_error_max           2619 non-null float64
# star_radius                   3302 non-null float64
# star_radius_error_min         3115 non-null float64
# star_radius_error_max         3115 non-null float64
# star_sp_type                  1256 non-null object
# star_age                      1029 non-null float64
# star_age_error_min            758 non-null float64
# star_age_error_max            760 non-null float64
# star_teff                     3503 non-null float64
# star_teff_error_min           3253 non-null float64
# star_teff_error_max           3253 non-null float64
# star_detected_disc            82 non-null object
# star_magnetic_field           4 non-null object
# star_alternate_names          292 non-null object
# dtypes: float64(84), object(14)
# memory usage: 2.8+ MB

# %%
df.isnull().sum()
# Out:
# # name                     0
# planet_status              0
# mass                    2146
# mass_error_min          2338
# mass_error_max          2352
#                         ...
# star_teff_error_min      479
# star_teff_error_max      479
# star_detected_disc      3650
# star_magnetic_field     3728
# star_alternate_names    3440
# Length: 98, dtype: int64

# %%
len(df) - df['mass'].isnull().sum()
# Out:
# 1586

# %%
data = df['star_distance']

data.describe()
# Out:
# count    2584.000000
# mean      605.089602
# std       844.370337
# min         1.295000
# 25%        74.800000
# 50%       435.500000
# 75%       860.250000
# max      8500.000000
# Name: star_distance, dtype: float64

# %%
import matplotlib.pyplot as plt

fig1, ax = plt.subplots()
ax.set_title('Plot')

ax.boxplot(data, vert=False)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1316: RuntimeWarning: invalid value encountered in less_equal
#   wiskhi = x[x <= hival]
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1323: RuntimeWarning: invalid value encountered in greater_equal
#   wisklo = x[x >= loval]
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1331: RuntimeWarning: invalid value encountered in less
#   x[x < stats['whislo']],
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1332: RuntimeWarning: invalid value encountered in greater
#   x[x > stats['whishi']],
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a2ba74550>,
#   <matplotlib.lines.Line2D at 0x1a2ba74ad0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a2ba74fd0>,
#   <matplotlib.lines.Line2D at 0x1a2ba74990>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1a2ba69ad0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a2ba7ba10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a2ba7bf10>],
#  'means': []}

# %%
import seaborn as sns
plt.figure(figsize=(20,5))
g = sns.boxplot(x = data, palette="Set2")
g.set_xticklabels(g.get_xticks(), size = 15)
g.axes.set_title("Boxplot of distances to exoplanet's star(s)",fontsize=30)
g.set_xlabel("Distance",fontsize=20);

# %%
import seaborn as sns

ax = sns.boxenplot(x = data)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
data2 = df[['star_distance', 'star_age', 'star_mass','mass','star_metallicity','orbital_period']]

# %%
sns.set(rc={'figure.figsize':(7, 7)})

# Use the .heatmap method to depict the relationships visually!
sns.heatmap(data2.corr());
